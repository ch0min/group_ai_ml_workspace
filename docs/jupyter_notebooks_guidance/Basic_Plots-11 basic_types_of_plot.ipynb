# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

slices = [7, 2, 2, 13]
activities = ['sleeping', 'eating', 'working', 'playing']

plt.pie(slices, 
        labels=activities, 
        explode=(0, 0, 0.2, 0),
        autopct='%1.1f%%'
       )
plt.show()

# %%
slices = [7, 2, 2, 13]
activities = ['sleeping', 'eating', 'working', 'playing']

plt.pie(slices, 
        labels=activities, 
        explode=(0, 0.2, 0, 0),
        autopct='%1.1f%%'
       )
plt.show()

# %%
input_data = {'first': [7,3,5,9, np.nan], 'second': [12,2,6,np.nan,5]}
df = pd.DataFrame(data=input_data, index=['1999', '2009','2012', '2019', '2021'])

# %%
df.plot(kind='line', title="The Line Graph Title")
# Out:
# <AxesSubplot:title={'center':'The Line Graph Title'}>

# %%
df.shape
# Out:
# (5, 2)

# %%
df.count
# Out:
# <bound method DataFrame.count of       first  second
# 1999    7.0    12.0
# 2009    3.0     2.0
# 2012    5.0     6.0
# 2019    9.0     NaN
# 2021    NaN     5.0>

# %%
type(df['second'])
# Out:
# pandas.core.series.Series

# %%
df_fill_zero = df.fillna(0)

# %%
df_fill_zero.count
# Out:
# <bound method DataFrame.count of       first  second
# 1999    7.0    12.0
# 2009    3.0     2.0
# 2012    5.0     6.0
# 2019    9.0     0.0
# 2021    0.0     5.0>

# %%
df_fill_prev = df.ffill()

# %%
df_fill_prev.count
# Out:
# <bound method DataFrame.count of       first  second
# 1999    7.0    12.0
# 2009    3.0     2.0
# 2012    5.0     6.0
# 2019    9.0     6.0
# 2021    9.0     5.0>

# %%
df_fill_prev = df.bfill()

# %%
df_fill_prev.count
# Out:
# <bound method DataFrame.count of       first  second
# 1999    7.0    12.0
# 2009    3.0     2.0
# 2012    5.0     6.0
# 2019    9.0     5.0
# 2021    NaN     5.0>

# %%
df_fill_prev = df.interpolate()

# %%
df_fill_prev.count
# Out:
# <bound method DataFrame.count of       first  second
# 1999    7.0    12.0
# 2009    3.0     2.0
# 2012    5.0     6.0
# 2019    9.0     5.5
# 2021    9.0     5.0>
